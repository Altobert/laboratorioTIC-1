# %% [markdown]
# <a href="https://colab.research.google.com/github/Altobert/laboratorioTIC-1/blob/main/Laboratorio1-Asm-Alondra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PRESENTACIÓN 1: Dataset Relacionado con la Calidad del Agua
#
# 1.	ammonia
# 2.	arsenic
# 3.	barium
# 4.	cadmium
# 5.	chloramine
# 6.	chromium
# 7.	copper
# 8.	flouride
# 9.	bacteria
# 10.	viruses
# 11.	lead
# 12.	nitrates
# 13.	nitrites
# 14.	mercury
# 15.	perchlorate
# 16.	radium
# 17.	selenium
# 18.	silver
# 19.	uranium
# 20.	is_safe
#
#
# **Integrantes**:
#
#
# * Alondra Villanueva
# * Alberto San Martín Concha

# %% [markdown]
# #Las siguientes variables indican la composicion del agua, dando por entender la calidad del agua de acuerdo a los siguientes componentes:
#
# **aluminium**
# **ammonia**
# arsenic
# barium
# cadmium
# chloramine
# chromium
# copper
# flouride
# bacteria
# viruses
# lead
# nitrates
# nitrites
# mercury
# perchlorate
# radium
# selenium
# silver
# uranium
# is_safe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Minor-DataScience/water-quality/waterQuality1.csv')
df.head()
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# ...
